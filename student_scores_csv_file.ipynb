# %%
import pandas as pd

# Create sample data for Student Performance
data = {
    'Student_ID': [101, 102, 103, 104, 105, 106, 107, 108],
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female'],
    'Study_Hours': [5, 7, 6, 3, 8, 4, 2, 9],
    'Attendance_%': [85, 92, 88, 70, 95, 75, 60, 98],
    'Assignments_Submitted': [8, 10, 9, 5, 10, 7, 4, 10],
    'Final_Score': [78, 88, 84, 65, 93, 70, 55, 96]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Save it as a CSV file
df.to_csv('student_scores.csv', index=False)

print("✅ student_scores.csv file created successfully!")
# Out:
# ✅ student_scores.csv file created successfully!
